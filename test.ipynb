# %%
# %load_ext autoreload
# %autoreload 2

from painter import Painter
import matplotlib.pyplot as plt
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
painter = Painter()

# %%
painter.encode_text('Art Nouveau delicate artwork, detailed, trending on Artstation.')

# %%
plt.imshow(painter.latents_to_image())

# %%
strokes = [
    {'x': 5, 'y': 5},
]
painter.paint(strokes)
plt.imshow(painter.latents_to_image())
